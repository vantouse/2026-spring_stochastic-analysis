# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

from stochastique.models.FHN import model_FHN, equilibria_FHN
from stochastique.analysis.simulation import simulate_trajectory, simulate_stochastic_cloud

# %%
N_STEPS_DEFAULT = 1000

# %% [markdown]
# # 1. Проведем сравнение стохастических решений для $a = 1.1$, $a = 1.01$
#
# (а) Построим графики $x(\varepsilon)$, пропустив переходный процесс $T = 100$.

# %%
from stochastique.analysis.excitement import localize_stochastic_excitement

# %%
rng = np.random.default_rng()

delta, a = 0.1, None
a_values = [1.1, 1.01]

time_span = np.linspace(0, 10, num=10 ** 3)
noise_mask = np.array([1, 0])   # add noise to 1st equation only
eps_values = np.linspace(0, 1, num=50)

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

for a, ax in zip(a_values, axes):
    params = dict(delta=delta, a=a)
    state_init = equilibria_FHN(**params)[0]

    localize_stochastic_excitement(
        model_func=model_FHN,
        params=params,
        state_init=state_init,
        time_span=time_span,
        noise_mask=noise_mask,
        eps_values=eps_values,
        num_simulations=1,
        rng=rng,
        ax=ax,
        highlight=False,
    )

    ax.set_title(rf'$\delta$ = {delta}, $a$ = {a}')
    ax.set_xlabel(r'$\varepsilon$')
    ax.set_ylabel(r'$x$')
    ax.legend()
# Out:
# Run multiple simulations: 100%|██████████| 1/1 [00:01<00:00,  1.32s/it]
# /tmp/ipykernel_6312/1045397707.py:32: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# Run multiple simulations: 100%|██████████| 1/1 [00:01<00:00,  1.28s/it]

# %% [markdown]
# Локализуем $\varepsilon$ зоны стохастического возбуждения.

# %%
from stochastique.analysis.excitement import localize_stochastic_excitement

# %%
rng = np.random.default_rng()

delta, a = 0.1, None
a_values = [1.1, 1.01]

time_span = np.linspace(0, 10, num=10 ** 3)
noise_mask = np.array([1, 0])   # add noise to 1st equation only
eps_values = np.linspace(0, 1, num=50)

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

for a, ax in zip(a_values, axes):
    params = dict(delta=delta, a=a)
    state_init = equilibria_FHN(**params)[0]

    localize_stochastic_excitement(
        model_func=model_FHN,
        params=params,
        state_init=state_init,
        time_span=time_span,
        noise_mask=noise_mask,
        eps_values=eps_values,
        num_simulations=10,
        rng=rng,
        ax=ax,
    )

    ax.set_title(rf'$\delta$ = {delta}, $a$ = {a}')
    ax.set_xlabel(r'$\varepsilon$')
    ax.set_ylabel(r'$x$')
    ax.legend()
# Out:
# Run multiple simulations: 100%|██████████| 10/10 [00:12<00:00,  1.28s/it]
# Run multiple simulations: 100%|██████████| 10/10 [00:12<00:00,  1.26s/it]

# %% [markdown]
# (б) Построим временные ряды при различных значениях $\varepsilon$: с возбуждением и без возбуждения.

# %%
rng = np.random.default_rng()

delta, a = 0.1, 1.1
eps_values = [
    (0.1, 'no excitement'),
    (0.4, 'excitement')
]

time_span = np.linspace(0, 100, num=10 ** 4)
noise_mask = np.array([1, 0])   # add noise to 1st equation only

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

for eps_state, ax in zip(eps_values, axes):
    eps, comment = eps_state
    params = dict(delta=delta, a=a)

    state_init = equilibria_FHN(**params)[0]
    trajectory = simulate_trajectory(
        model_func=model_FHN,
        params=params,
        state_init=state_init,
        time_span=time_span,
        epsilon=eps,
        noise_mask=noise_mask,
        rng=rng,
    )
    # trajectory = trajectory[100:]   # clip transient
    trajectory_x = trajectory[:, 0]
    
    ax.plot(time_span, trajectory_x)
    ax.set_title(rf'$\delta$ = {delta}, $a$ = {a} ($\varepsilon$ = {eps}, {comment})')
    ax.set_xlabel(r'$t$')
    ax.set_ylabel(r'$x$')

# %%
rng = np.random.default_rng()

delta, a = 0.1, 1.01
eps_values = [
    (0.05, 'no excitement'),
    (0.2, 'excitement')
]

time_span = np.linspace(0, 100, num=10 ** 4)
noise_mask = np.array([1, 0])   # add noise to 1st equation only

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

for eps_state, ax in zip(eps_values, axes):
    eps, comment = eps_state
    params = dict(delta=delta, a=a)

    state_init = equilibria_FHN(**params)[0]
    trajectory = simulate_trajectory(
        model_func=model_FHN,
        params=params,
        state_init=state_init,
        time_span=time_span,
        epsilon=eps,
        noise_mask=noise_mask,
        rng=rng,
    )
    # trajectory = trajectory[100:]   # clip transient
    trajectory_x = trajectory[:, 0]
    
    ax.plot(time_span, trajectory_x)
    ax.set_title(rf'$\delta$ = {delta}, $a$ = {a} ($\varepsilon$ = {eps}, {comment})')
    ax.set_xlabel(r'$t$')
    ax.set_ylabel(r'$x$')

# %% [markdown]
# # 2. Построим доверительные эллипсы в допороговой и надпороговой зонах для $a = 1.1$, $a = 1.01$

# %%
from stochastique.core.dynamic import DynamicSystem2D
from stochastique.core.numerical import stochastic_sensitivity_matrix_2d
from stochastique.util.plot import plot_confidence_ellipse_2d

# %%
delta, a = 0.1, 1.1
eps_values = [
    (0.1, 'no excitement'),
    (0.2, 'excitement'),
    # (0.0, 'no excitement'),
    # (0.0, 'excitement'),
]

time_span = np.linspace(0, 100, num=10 ** 4)
noise_mask = np.array([1, 0])   # add noise to 1st equation only

# eps, comment = eps_values[0]
params = dict(delta=delta, a=a)
equilibrium = equilibria_FHN(**params)[0]

FHN = DynamicSystem2D(
    model_FHN,
    params=dict(delta=0.1, a=1)
)

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

for eps_state, ax in zip(eps_values, axes):
    eps, comment = eps_state
    FHN.params['a'] = a
    FHN.plot_phase_portrait_dense(
        ax=ax,
        time_span=time_span,
        bounds=(-2, 2),
        grid_size=10,
        seacrh_limit_cycles=False,
    )

    W = stochastic_sensitivity_matrix_2d(
        model_func=model_FHN,
        params=dict(delta=delta, a=a),
        equilibrium=equilibrium,
        noise_mask=noise_mask,
    )

    plot_confidence_ellipse_2d(
        ax=ax,
        equilibrium=equilibrium,
        W=W,
        epsilon=eps,
        major_axes=True,
    )

    simulate_stochastic_cloud(
        ax=None,
        model_func=model_FHN,
        params=params,
        state_init=equilibrium,
        time_span=time_span,
        epsilon=eps,
        noise_mask=noise_mask,
        num_simulations=1,
    )

    ax.set_title(rf'FHN ($\delta$ = {delta}, $a$ = {a}, $\varepsilon$ = {eps}), {comment}')
# Out:
# Test trajectories and search cycles:   0%|          | 0/100 [00:00<?, ?it/s]
# Test trajectories and search cycles: 100%|██████████| 100/100 [00:19<00:00,  5.20it/s]
# Test trajectories and search cycles: 100%|██████████| 100/100 [00:18<00:00,  5.38it/s]

# %%
delta, a = 0.1, 1.01
eps_values = [
    (0.05, 'no excitement'),
    (0.2, 'excitement')
]

time_span = np.linspace(0, 100, num=10 ** 4)
noise_mask = np.array([1, 0])   # add noise to 1st equation only

# eps, comment = eps_values[0]
params = dict(delta=delta, a=a)
equilibrium = equilibria_FHN(**params)[0]

FHN = DynamicSystem2D(
    model_FHN,
    params=dict(delta=0.1, a=1)
)

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

for eps_state, ax in zip(eps_values, axes):
    eps, comment = eps_state
    FHN.params['a'] = a
    FHN.plot_phase_portrait_dense(
        ax=ax,
        time_span=time_span,
        bounds=(-1.5, 1.5),
        grid_size=10,
        seacrh_limit_cycles=False,
    )

    W = stochastic_sensitivity_matrix_2d(
        model_func=model_FHN,
        params=dict(delta=delta, a=a),
        equilibrium=equilibrium,
        noise_mask=noise_mask,
    )

    plot_confidence_ellipse_2d(
        ax=ax,
        equilibrium=equilibrium,
        W=W,
        epsilon=eps,
        major_axes=True,
    )

    # ax.plot(trajectory[:, 0], trajectory[:, 1], alpha=0.3, label='trajectory')

    simulate_stochastic_cloud(
        ax=None,
        model_func=model_FHN,
        params=params,
        state_init=equilibrium,
        time_span=time_span,
        epsilon=eps,
        noise_mask=noise_mask,
        num_simulations=1,
    )
    ax.set_title(rf'FHN ($\delta$ = {delta}, $a$ = {a}, $\varepsilon$ = {eps}), {comment}')
# Out:
# Test trajectories and search cycles: 100%|██████████| 100/100 [00:18<00:00,  5.27it/s]
# Test trajectories and search cycles: 100%|██████████| 100/100 [00:18<00:00,  5.36it/s]
